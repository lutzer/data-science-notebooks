# %% [markdown]
# # 00 - Main
#
# Run this script to execute all other scripts sequenctially. Check `output` folder if errors occur.

# %%
import papermill as pm
from pathlib import Path

notebooks = [
    "01_setup.ipynb",
    "02_grid.ipynb",
    "11_sea_proximity.ipynb",
    "12_terrain_ruggedness.ipynb",
    "13_sun_hours.ipynb",
    "14_temperature_pleasantness.ipynb",
    "15_annual_greenness.ipynb",
    "16_precipitation_balance.ipynb",
    "17_air_quality.ipynb",
    "18_natural_disaster_risk.ipynb",
    "19_climate_vulnerability.ipynb",
    "21_population_density.ipynb",
    "22_urbanity.ipynb",
    "23_internet_connectivity.ipynb",
    "24_healthcare_access.ipynb",
    "31_income.ipynb",
    "32_cost_of_living.ipynb",
    "33_crime_rate.ipynb",
    "34_human_freedom.ipynb",
    "35_corruption.ipynb",
    "91_distribution_analyses.ipynb",
    "92_normalization.ipynb",
    "94_post_processing.ipynb",
    "97_scoring.ipynb",
    "98_dashboard_export.ipynb",
]
output_dir = Path("output")
output_dir.mkdir(parents=True, exist_ok=True)

for nb in notebooks:
    print(f"Running notebook: {nb}")
    pm.execute_notebook(
        input_path=nb,
        output_path=str(output_dir / nb.replace(".ipynb", "_output.ipynb")),
        extra_arguments=["--log-level=ERROR"],
    )

print("All notebooks ran successfully.")
# Out:
# Running notebook: 01_setup.ipynb
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# Running notebook: 02_grid.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Running notebook: 11_sea_proximity.ipynb
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Running notebook: 12_terrain_ruggedness.ipynb
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Running notebook: 13_sun_hours.ipynb
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Running notebook: 14_temperature_pleasantness.ipynb
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Running notebook: 15_annual_greenness.ipynb
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Running notebook: 16_precipitation_balance.ipynb
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]
# Running notebook: 17_air_quality.ipynb
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Running notebook: 18_natural_disaster_risk.ipynb
# Executing:   0%|          | 0/23 [00:00<?, ?cell/s]
# ...

# %% [markdown]
# # 2. Run only the export for the dashobard

# %%
import papermill as pm
from pathlib import Path

notebooks = [
    "92_normalization.ipynb",
    "94_post_processing.ipynb",
    "97_scoring.ipynb",
    "98_dashboard_export.ipynb",
]
output_dir = Path("output")
output_dir.mkdir(parents=True, exist_ok=True)

for nb in notebooks:
    print(f"Running notebook: {nb}")
    pm.execute_notebook(
        input_path=nb,
        output_path=str(output_dir / nb.replace(".ipynb", "_output.ipynb")),
        extra_arguments=["--log-level=ERROR"],
    )

print("All notebooks ran successfully.")
# Out:
# Running notebook: 91_distribution_analyses.ipynb
# Executing:   0%|          | 0/24 [00:00<?, ?cell/s]
# Running notebook: 92_normalization.ipynb
# Executing:   0%|          | 0/10 [00:00<?, ?cell/s]
# Running notebook: 94_post_processing.ipynb
# Executing:   0%|          | 0/4 [00:00<?, ?cell/s]
# Running notebook: 97_scoring.ipynb
# Executing:   0%|          | 0/10 [00:00<?, ?cell/s]
# Running notebook: 98_dashboard_export.ipynb
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
