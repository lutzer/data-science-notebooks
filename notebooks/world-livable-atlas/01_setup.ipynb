# %% [markdown]
# # 00 - Setup
#
# Setup the development environment

# %% [markdown]
# ## 1 Setup Environment
# Installs all necessary dependencies and setups the dev environment

# %%
# %pip install netCDF4
# %pip install regionmask
# %pip install xarray
# %pip install tqdm
# %pip install httpx
# %pip install ipywidgets
# %pip install scipy
# %pip install dbfread
# %pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 12.9 MB/s  0:00:02m0:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.
